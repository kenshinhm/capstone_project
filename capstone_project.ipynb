# %% [markdown]
# # Capstone Project for Investment and Trading

# %% [markdown]
# In this project, we will try to refute Efficient Market Hypothesis by outperforming the market index. Following active management, We will construct a portfolio of stocks with help of machine learning to simply do better than the market index, S&P500
# Followings are step by step strategies to achieve our desired goal:
#
# 1) Predict S&P500 future return from current input features: daily, weekly S&P500 return, other market return index(DAX, NIK), trade volume, price of commodities, and so on.
#
# 2) For every stocks in S&P500, run regression to fit a line where x is S&P500 and y is an individual stock. Gradient of this fitted line is called beta in CAPM theory and it signals how stock move relative to the market.
#
# 3) We now have to select proper stocks depending on our S&P500 future forecast. Our solution guides us to select high beta stocks when market is expected to rise and select low beta stocks vice versa. Detail explanation will be given later for this logic.
#
# 4) After selecting bucket of stocks, we seek for optimal allocation weight for each stock that maximize portfolio's return or risk adjusted return.
#
# 5) In simulation, we will iterate step 1) - 4) for daily basis.

# %% [markdown]
# <font color='gray' size=4> (1) Predict S&P500: Sourcing market Data from Quandl </font>

# %% [markdown]
# This script is for downloading financial data required for predicting S&P500 daily return. Source is from Quandl API and <font color='red'>do not need to run this</font> since everything is already downloaded as parsed as CSV files in local directories. There are many options for representing stock price data. In this project we will only use adjusted close price, because this compensates for any price anomaly resulting from dividends or stock split.

# %%
import quandl
import utility as util
import process as proc

quandl.ApiConfig.api_key = "dmDantC6pfu5ZsSZ9Zny"

date_range = ["2010-01-01", "2016-12-31"]
#spy: S&P500 index
spy = quandl.get("YAHOO/INDEX_GSPC", start_date=date_range[0], end_date=date_range[1])
#nasdaq: NASDAQ composite index
nas = quandl.get("YAHOO/INDEX_IXIC", start_date=date_range[0], end_date=date_range[1])
#dax: German stock market index
dax = quandl.get("YAHOO/INDEX_GDAXI", start_date=date_range[0], end_date=date_range[1])
#nikkei 225: Japan stock market index
nik = quandl.get("YAHOO/INDEX_N225", start_date=date_range[0], end_date=date_range[1])
#kpi: KOSPI index from Korea
#kpi = quandl.get("YAHOO/INDEX_KS11", start_date=date_range[0], end_date=date_range[1])
#glf: Chicago Merchandile Exchange NYMEX Gold Futures
glf = quandl.get("CHRIS/CME_GC1", start_date=date_range[0], end_date=date_range[1])
#oif: Crude Oil Futures based on spot-month continuous contract 
olf = quandl.get("CHRIS/CME_CL1", start_date=date_range[0], end_date=date_range[1])

spy = spy.rename(columns = {'Volume':'SPY:Volume', 'Adjusted Close':'SPY:Price'})
nas = nas.rename(columns = {'Volume':'NAS:Volume', 'Adjusted Close':'NAS:Price'})
dax = dax.rename(columns = {'Volume':'DAX:Volume', 'Adjusted Close':'DAX:Price'})
nik = nik.rename(columns = {'Volume':'NIK:Volume', 'Adjusted Close':'NIK:Price'})
#kpi = kpi.rename(columns = {'Volume':'KPI:Volume', 'Adjusted Close':'KPI:Price'})
glf = glf.rename(columns = {'Volume':'GLF:Volume', 'Settle':'GLF:Price'})
olf = olf.rename(columns = {'Volume':'OLF:Volume', 'Settle':'OLF:Price'})

#Set date index from spy as a reference
date_index = spy.index.get_values()

#Get processed dataframe
df = proc.get_mkt_data(date_index, spy, nas, dax, nik, glf, olf)

#Save data to csv file
util.save_data('mkt_price_volume.csv',df)

# %%
import quandl
import utility as util

IBM = quandl.get("WIKI/IBM", start_date="1975-01-01", end_date="1985-01-01")
util.plot_data(IBM[['Close', 'Adj. Close']], 'IBM', xlable='Date', ylable='Price')

# %% [markdown]
# Before actually touching on some data, lets explore, visualize, and find out some statistics.

# %%
import utility as util
import process as proc

util.plot_data(spy['SPY:Price'].ix["2016-01-04":"2016-01-30"], 'S&P500 Price', xlable ='Date', ylable='Price')
util.plot_data(spy['SPY:Price'], 'S&P500 Price', xlable ='Date', ylable='Price')
util.plot_histogram(spy[['SPY:Price']], 'S&P500 Price distribution', xlable ='Price', ylable='Freq')
util.plot_data(spy['SPY:Volume'], 'S&P500 Volume', xlable ='Date', ylable='Volume')
util.plot_histogram(spy[['SPY:Volume']], 'S&P500 Volume distribution', xlable ='Volume', ylable='Freq')
print "Statistics for S&P500 Price"
proc.print_statistics(spy[['SPY:Price']])
print ""
print "Statistics for S&P500 Volume"
proc.print_statistics(spy[['SPY:Volume']])
# Out:
# Statistics for S&P500 Price
#      statistic           value
# ------------------------------
#           size      1762.00000
#            min      1022.58002
#            max      2271.71997
#           mean      1645.70950
#            std       371.29317
#           skew        -0.01582
#       kurtosis        -1.53155
#
# Statistics for S&P500 Volume
#      statistic           value
# ------------------------------
#           size      1762.00000
#            min 536200000.00000
#            max 10617809600.00000
#           mean 3796473024.74461
#            std 879457321.79412
#           skew         1.06084
#       kurtosis         4.83376

# %% [markdown]
# <font color='gray' size=4> (2) Predict S&P500: Preprocessing input features </font>

# %% [markdown]
# First step with dealing financial data is to fill missing values for every columns. Instead of using interpolation, we will just fill with latest value. This is to avoid information leaking into future to prevent optimistic result. Finally, we are ready to process input data to our learning models. However, if you see the distribution of stock price, it seems to follow somewhat binomial distribution. Hence, instead of just using price data we will turn it to a daily return. We can see that daily return, not exactly though because of fat tail, shows normal distribution. Refer to some statistics below for our daily return distribution.

# %%
import utility as util
import process as proc
from IPython.display import display # Allows the use of display() for DataFrames
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

day_1 = 1
day_5 = 5
day_10 = 10
day_20 = 20

# Show matplotlib plots inline (nicely formatted in the notebook)
# %matplotlib inline

# Read data from CSV files
mkt_df = proc.read_mkt_data('mkt_price_volume.csv')
# Display a description of the dataset
#display(mkt_df.describe())

# Fill missing value
data_before = proc.fill_missing_values(mkt_df)

# Divide data into categories(stock index, commodity, interest rates)
stock_price = data_before[['SPY:Price', 'NAS:Price', 'DAX:Price', 'NIK:Price']]
commodity_price = data_before[['GLF:Price', 'OLF:Price']]

# Before Preprocessing data
util.plot_data(stock_price, 'stock price')
util.plot_histogram(stock_price[['SPY:Price']], 'S&P500 distribution')

# Preprocess: Price to Daily Returns, this also changes volume to daily increase
data_after = proc.price_to_return(data_before, 'Price', 'Return', day_10)

# Divide data into categories(stock index, commodity, interest rates)
stock_return = data_after[['SPY:Return', 'NAS:Return', 'DAX:Return', 'NIK:Return']]
commodity_return = data_after[['GLF:Return', 'OLF:Return']]

# After Preprocessing data
util.plot_data(stock_return, 'stock return')
util.plot_histogram(stock_return[['SPY:Return']], 'S&P500 distribution')

print "Statistics for SPY:Return"
proc.print_statistics(stock_return['SPY:Return'])
# Out:
# Statistics for SPY:Return
#      statistic           value
# ------------------------------
#           size      1762.00000
#            min         0.83702
#            max         1.09246
#           mean         1.00425
#            std         0.02691
#           skew        -0.78328
#       kurtosis         2.49443

# %% [markdown]
# We can apply same converting logic to volume data. Volume means trade volume, quantity of an order made in each day. As you can see from below figure however, raw volume data is acts like somewhat normal distribution. In addition to this raw data, we will add rolling mean for n day. This is because, at first I thought that if we can see some trend of volume movement it might help in describing market movement.

# %%
# Divide data into categories(stock index, commodity, interest rates)
volume = data_before[['SPY:Volume']]

# Preprocess
rolling_volume = proc.get_rolling_mean(spy_volume, day_10)
rolling_volume = proc.fill_missing_values(spy_rolling_volume)

# Before Preprocessing data
util.plot_histogram(volume, 'S&P500 spot volume distribution')
print "Statistics for SPY:Volume"
proc.print_statistics(volume['SPY:Volume'])

# After Preprocessing data
util.plot_histogram(rolling_volume, 'S&P500 rolling 10 days volume distribution')
print "Statistics for SPY:Volume(10D)"
proc.print_statistics(rolling_volume['SPY:Volume'])
# Out:
# Statistics for SPY:Volume
#      statistic           value
# ------------------------------
#           size      1762.00000
#            min 536200000.00000
#            max 10617809600.00000
#           mean 3796473024.74461
#            std 879457321.79412
#           skew         1.06084
#       kurtosis         4.83376
# Statistics for SPY:Volume(10D)
#      statistic           value
# ------------------------------
#           size      1762.00000
#            min 1626553000.00000
#            max 7121765000.00000
#           mean 3801428562.76958
#            std 655254810.13675
#           skew         1.15130
#       kurtosis         3.04685

# %% [markdown]
# <font color='gray' size=4> (3) Predict S&P500: Selecting features </font>

# %% [markdown]
# Our goal is to predict S&P500 return, whether it's price is expected to go up or down. Our portfolio strategy heavily depends on this prediction. In order to predict S&P500 movement, we have selected various features from above. In this section, we will find relevant features for predicting S&P500 return.

# %%
import pandas as pd
import utility as util
import process as proc
from IPython.display import display # Allows the use of display() for DataFrames
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

# Show matplotlib plots inline (nicely formatted in the notebook)
# %matplotlib inline

# Read data from CSV files
raw_data = proc.read_mkt_data('mkt_price_volume.csv')

day_1 = 1
day_5 = 5
day_10 = 10
day_20 = 20

# Fill missing value
raw_data = proc.fill_missing_values(raw_data)
price_data = proc.extract_columns(raw_data, 'Price')
day_1_return = proc.price_to_return(price_data, 'Price', 'Return(1D)', day_1)
day_5_return = proc.price_to_return(price_data, 'Price', 'Return(5D)', day_5)
day_10_return = proc.price_to_return(price_data, 'Price', 'Return(10D)', day_10)
day_20_return = proc.price_to_return(price_data, 'Price', 'Return(20D)', day_20)

#target
target = day_10_return['SPY:Return(10D)'].shift(-5)
target.name = target.name.replace('Return(10D)', 'Target')

#ScatterPlot
df = day_10_return
df = df.join(target)
df = df[['SPY:Target', 'GLF:Return(10D)', 'SPY:Return(10D)', 'NAS:Return(10D)']]
pd.scatter_matrix(df, alpha = 0.3, figsize = (14,12), diagonal = 'kde');
print df.corr(method='pearson')
# Out:
#                  SPY:Target  GLF:Return(10D)  SPY:Return(10D)  NAS:Return(10D)
# SPY:Target         1.000000        -0.033123         0.429326         0.393964
# GLF:Return(10D)   -0.033123         1.000000        -0.003888        -0.009722
# SPY:Return(10D)    0.429326        -0.003888         1.000000         0.951875
# NAS:Return(10D)    0.393964        -0.009722         0.951875         1.000000

# %% [markdown]
# SPY is ticker for S&P500 index, and SPY:Target means future 10-day cumulative return for S&P500 starting from 5days ago. From above scatterplot, we can see that GLF(Gold Future) has low correlation with our SPY:Target value. It means that we can hardly explain our future S&P500 movement with gold future. I have tried various duration for gold future such as 1,5,10,20,30 day cumulative return, but none had meaningful result. Also, we will drop NAS(nasdaq) since this feature move almost the same as SPY(S&P500). After removing let's add some S&P500 1day, 5day, 20day ago cumulative return to our feature sets. In general, technical analyst use this n-day trailing data for extracting a signal for market trend.

# %%
df.drop('GLF:Return(10D)', axis = 1, inplace = True)
df.drop('NAS:Return(10D)', axis = 1, inplace = True)
df = df.join(day_1_return['SPY:Return(1D)'])
df = df.join(day_5_return['SPY:Return(5D)'])
df = df.join(day_20_return['SPY:Return(20D)'])

print df.corr(method='pearson')
pd.scatter_matrix(df, alpha = 0.3, figsize = (14,12), diagonal = 'kde');
# Out:
#                  SPY:Return(10D)  DAX:Return(10D)  NIK:Return(10D)  \
# SPY:Return(10D)         1.000000         0.764184         0.624404
# DAX:Return(10D)         0.764184         1.000000         0.616134
# NIK:Return(10D)         0.624404         0.616134         1.000000
# OLF:Return(10D)         0.432435         0.322211         0.255030
# SPY:Target              0.429326         0.320363         0.226382
# SPY:Return(1D)          0.279484         0.167645         0.024329
# SPY:Return(5D)          0.644749         0.490386         0.353469
# SPY:Return(20D)         0.663314         0.538692         0.479655
#
#                  OLF:Return(10D)  SPY:Target  SPY:Return(1D)  SPY:Return(5D)  \
# SPY:Return(10D)         0.432435    0.429326        0.279484        0.644749
# DAX:Return(10D)         0.322211    0.320363        0.167645        0.490386
# NIK:Return(10D)         0.255030    0.226382        0.024329        0.353469
# OLF:Return(10D)         1.000000    0.222915        0.123317        0.288615
# SPY:Target              0.222915    1.000000        0.263315        0.656719
# SPY:Return(1D)          0.123317    0.263315        1.000000        0.423602
# SPY:Return(5D)          0.288615    0.656719        0.423602        1.000000
# SPY:Return(20D)         0.257701    0.277337        0.195323        0.452920
#
#                  SPY:Return(20D)
# SPY:Return(10D)         0.663314
# DAX:Return(10D)         0.538692
# NIK:Return(10D)         0.479655
# OLF:Return(10D)         0.257701
# SPY:Target              0.277337
# SPY:Return(1D)          0.195323
# SPY:Return(5D)          0.452920
# SPY:Return(20D)         1.000000

# %% [markdown]
# Now, lets dive into volume data. For volume we will treat only volume data for S&P500. We will preprocess our raw volume data into rolling mean datas.

# %%
volume_data = proc.extract_columns(raw_data, 'Volume')
spy_volume = volume_data['SPY:Volume']
day_1_volume = proc.get_rolling_mean(spy_volume, day_1)
day_1_volume.name = spy_volume.name.replace('Volume', 'Volume(1D)')
day_5_volume = proc.get_rolling_mean(spy_volume, day_5)
day_5_volume.name = spy_volume.name.replace('Volume', 'Volume(5D)')
day_10_volume = proc.get_rolling_mean(spy_volume, day_10)
day_10_volume.name = spy_volume.name.replace('Volume', 'Volume(10D)')
day_20_volume = proc.get_rolling_mean(spy_volume, day_20)
day_20_volume.name = spy_volume.name.replace('Volume', 'Volume(20D)')

df = pd.DataFrame(index=target.index.get_values())
df = df.join(day_1_volume)
df = df.join(day_5_volume)
df = df.join(day_10_volume)
df = df.join(day_20_volume)
df = df.join(target)
df = proc.fill_missing_values(df)

print df.corr(method='pearson')
pd.scatter_matrix(df, alpha = 0.3, figsize = (14,12), diagonal = 'kde');
# Out:
#                  SPY:Volume(1D)  SPY:Volume(5D)  SPY:Volume(10D)  \
# SPY:Volume(1D)         1.000000        0.780958         0.693605
# SPY:Volume(5D)         0.780958        1.000000         0.916926
# SPY:Volume(10D)        0.693605        0.916926         1.000000
# SPY:Volume(20D)        0.621578        0.808972         0.914313
# SPY:Target            -0.121729       -0.084534        -0.040558
#
#                  SPY:Volume(20D)  SPY:Target
# SPY:Volume(1D)          0.621578   -0.121729
# SPY:Volume(5D)          0.808972   -0.084534
# SPY:Volume(10D)         0.914313   -0.040558
# SPY:Volume(20D)         1.000000   -0.045456
# SPY:Target             -0.045456    1.000000

# %% [markdown]
# Unfortunately, we could not find any relavance between rolling mean of volume of S&P500 and future cumulative return of S&P500. To summarize, with regards to feature inputs, we will use 10 day cumulative return from SPY, DAX, NIK, OLF and daily return, 5-day cumulative return, and 20-day cumulative return for S&P500. All this inputs are for predicting future S&P500 index.

# %% [markdown]
# <font color='gray' size=4> (4) Predict S&P500: Model Learning & Validation </font>

# %% [markdown]
# Now we are ready to learn our model. First, we will preprocess raw data, drop and select some features. Details can be found (3) Selecting Features.

# %%
import pandas as pd
import utility as util
import process as proc
from IPython.display import display # Allows the use of display() for DataFrames
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

# Show matplotlib plots inline (nicely formatted in the notebook)
# %matplotlib inline

day_1 = 1
day_5 = 5
day_10 = 10
day_20 = 20

# Read data from CSV files
raw_data = proc.read_mkt_data('mkt_price_volume.csv')

# Fill missing value
raw_data = proc.fill_missing_values(raw_data)
price_data = proc.extract_columns(raw_data, 'Price')
price_data.drop('GLF:Price', axis = 1, inplace = True)
price_data.drop('NAS:Price', axis = 1, inplace = True)

day_1_return = proc.price_to_return(price_data, 'Price', 'Return(1D)', day_1)
day_5_return = proc.price_to_return(price_data, 'Price', 'Return(5D)', day_5)
day_10_return = proc.price_to_return(price_data, 'Price', 'Return(10D)', day_10)
day_20_return = proc.price_to_return(price_data, 'Price', 'Return(20D)', day_20)

#target
target = day_10_return['SPY:Return(10D)'].shift(-5)
target.name = target.name.replace('Return(10D)', 'Target')

#features
df = day_10_return
df = df.join(day_1_return['SPY:Return(1D)'])
df = df.join(day_5_return['SPY:Return(5D)'])
df = df.join(day_20_return['SPY:Return(20D)'])

print df.head()
# Out:
#             SPY:Return(10D)  DAX:Return(10D)  NIK:Return(10D)  \
# 2010-01-04              1.0              1.0              1.0
# 2010-01-05              1.0              1.0              1.0
# 2010-01-06              1.0              1.0              1.0
# 2010-01-07              1.0              1.0              1.0
# 2010-01-08              1.0              1.0              1.0
#
#             OLF:Return(10D)  SPY:Return(1D)  SPY:Return(5D)  SPY:Return(20D)
# 2010-01-04              1.0        1.000000             1.0              1.0
# 2010-01-05              1.0        1.003116             1.0              1.0
# 2010-01-06              1.0        1.000546             1.0              1.0
# 2010-01-07              1.0        1.004001             1.0              1.0
# 2010-01-08              1.0        1.002882             1.0              1.0

# %% [markdown]
# We will divide our data into training sets and testing set. We will use 2010-2015 data for training and 2015-2016 data for simulating our portfolio strategy. But before that, we have to take care of some NaN values and fake values that come from rolling mean and cumultavie mean. Simply, we will exclude meaningless data. Front 20, and last 20 data will be removed.

# %%
train_range = ["2010-01-01", "2015-12-31"]
test_range = ["2016-01-01", "2016-12-31"]

df_after = df[day_20:-day_20]
target_after = target[day_20:-day_20]

X_train = df_after.ix[train_range[0]:train_range[1]]
y_train = target_after.ix[train_range[0]:train_range[1]]
X_test = df_after.ix[test_range[0]:test_range[1]]
y_test= target_after.ix[test_range[0]:test_range[1]]

print X_train.head()
print X_test.tail()

X_train = X_train.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)
# Out:
#             SPY:Return(10D)  DAX:Return(10D)  NIK:Return(10D)  \
# 2010-02-02         0.959217         0.955355         0.963417
# 2010-02-03         0.964184         0.969335         0.968970
# 2010-02-04         0.952198         0.962810         0.952851
# 2010-02-05         0.976579         0.954176         0.949629
# 2010-02-08         0.963493         0.973981         0.946648
#
#             OLF:Return(10D)  SPY:Return(1D)  SPY:Return(5D)  SPY:Return(20D)
# 2010-02-02         0.977348        1.012973        1.010209         0.973813
# 2010-02-03         0.991755        0.994526        0.999800         0.965474
# 2010-02-04         0.961356        0.968859        0.980249         0.934898
# 2010-02-05         0.955058        1.002897        0.992848         0.933870
# 2010-02-08         0.955222        0.991137        0.970207         0.922933
#             SPY:Return(10D)  DAX:Return(10D)  NIK:Return(10D)  \
# 2016-11-25         1.021163         1.006505         1.059777
# 2016-11-28         1.017219         0.992006         1.056525
# 2016-11-29         1.018695         0.993155         1.035898
# 2016-11-30         1.008448         0.991165         1.036242
# 2016-12-01         1.006495         0.987826         1.036441
#
#             OLF:Return(10D)  SPY:Return(1D)  SPY:Return(5D)  SPY:Return(20D)
# 2016-11-25         1.031348        1.003914        1.011993         1.037651
# 2016-11-28         1.084543        0.994745        1.009084         1.035417
# 2016-11-29         1.044090        1.001335        1.002948         1.036926
# 2016-11-30         1.079240        0.997347        0.998125         1.041241
# 2016-12-01         1.120474        0.996484        0.993813         1.044396

# %% [markdown]
# Typical usage of cross validation does not fit financial data application well. The reason is that it can permit peeking into the future. For instance, if our training data is after testing data that means we are seeing the future ahead of our test. Any sort of peeking like this can read to unrealistically optimistic results. This is why we divided train(2010-2015), test(2015-2016) sets in chronogical order rather than using train_test_split function from sklearn.cross_validation. One way to avoid this problem is with role forward cross validation. That mean our training data is always before testing data. And we can still have multiple trials just by rolling our data forward till we run out of data.

# %%
import run
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVR
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestRegressor

reg_knn = KNeighborsRegressor()
reg_dt = DecisionTreeRegressor()
reg_svr = SVR()
reg_rf = RandomForestRegressor()

params_knn = {'n_neighbors': range(5,31), 'weights': ['uniform','distance']}
params_dt = {'max_depth': range(1,10)}
params_svr = {'kernel': ['rbf', 'linear'], 
              'C': [0.1, 1.0, 3.0, 10.0],
              'epsilon': [0.001, 0.01, 0.03, 0.1]}
params_rf = {'n_estimators': [20,30,40],
             'max_depth': range(1,10)}

# Fit the training data to the model using grid search
#reg = run.fit_regression(reg_dt, X_train, y_train, params_dt)
#reg = run.fit_regression(reg_knn, X_train, y_train, params_knn)
#reg = run.fit_regression(reg_svr, X_train, y_train, params_svr)
reg = run.fit_regression(reg_rf, X_train, y_train, params_rf)

# Produce the value for 'max_depth'
print "Parameter 'max_depth' is {} for the optimal model.".format(reg.get_params()['max_depth'])
print "Parameter 'n_estimators' is {} for the optimal model.".format(reg.get_params()['n_estimators'])

#print "Parameter 'kernel' is {} for the optimal model.".format(reg.get_params()['kernel'])
#print "Parameter 'C' is {} for the optimal model.".format(reg.get_params()['C'])
#print "Parameter 'epsilon' is {} for the optimal model.".format(reg.get_params()['epsilon'])

#print "Parameter 'n_neighbors' is {} for the optimal model.".format(reg.get_params()['n_neighbors'])
#print "Parameter 'weights' is {} for the optimal model.".format(reg.get_params()['weights'])

print run.get_r2_score(reg, X_test, y_test)
# Out:
# Parameter 'max_depth' is 3 for the optimal model.
# Parameter 'n_estimators' is 20 for the optimal model.
# 0.512570661714

# %% [markdown]
# <font color='gray' size=4> (5) Portfolio Construction Strategy: Selecting Stocks </font>

# %% [markdown]
# To construct market beating portfolio, we should select appropriate stocks depending on market. For instance, we would select high beta stocks if we are in bull market and low beta stock if in bear market
#
# We will use stocks from S&P500 list for constructing portfolio. Below is code for downloading financial data for stocks that are constitunt of S&P500. Do not run this code because it will take too much time.

# %%
import quandl
import process as proc
import utility as util

quandl.ApiConfig.api_key = "dmDantC6pfu5ZsSZ9Zny"

mkt_df = proc.read_mkt_data('mkt_price_volume.csv')
date_range = ["2010-01-01", "2016-12-31"]
date_index = mkt_df.index.get_values()
 
stock_df = proc.get_total_stocks('S&P500_list.csv', date_index, date_range)
util.save_data('S&P500_stocks_price.csv', stock_df)
# Out:
# 0. 3M Company Download & Parse complete
# 1. Abbott Laboratories Download & Parse complete
# 2. AbbVie Download & Parse complete
# 3. Accenture plc Download & Parse complete
# 4. ACE Limited Download & Parse complete
# 5. Activision Blizzard Download & Parse complete
# 6. Adobe Systems Inc Download & Parse complete
# 7. ADT Corp Download & Parse complete
# 8. Advance Auto Parts Download & Parse complete
# 9. AES Corp Download & Parse complete
# 10. Aetna Inc Download & Parse complete
# 11. AFLAC Inc Download & Parse complete
# 12. Affiliated Managers Group Inc Download & Parse complete
# 13. Agilent Technologies Inc Download & Parse complete
# 14. AGL Resources Inc. Download & Parse complete
# 15. Air Products & Chemicals Inc Download & Parse complete
# 16. Airgas Inc Download & Parse complete
# 17. Akamai Technologies Inc Download & Parse complete
# 18. Alcoa Inc Download & Parse complete
# 19. Allergan plc Download & Parse complete
# 20. Alexion Pharmaceuticals Download & Parse complete
# 21. Allegion Download & Parse complete
# 22. Alliance Data Systems Download & Parse complete
# 23. Allstate Corp Download & Parse complete
# 24. Alphabet Inc Class A Download & Parse complete
# 25. Alphabet Inc Class C Download & Parse complete
# 26. Altera Corp Download & Parse complete
# 27. Altria Group Inc Download & Parse complete
# 28. Amazon.com Inc Download & Parse complete
# 29. Ameren Corp Download & Parse complete
# 30. American Airlines Group Download & Parse complete
# 31. American Electric Power Download & Parse complete
# 32. American Express Co Download & Parse complete
# 33. American International Group Download & Parse complete
# 34. American Tower Corp A Download & Parse complete
# 35. Ameriprise Financial Download & Parse complete
# 36. AmerisourceBergen Corp Download & Parse complete
# 37. Ametek Download & Parse complete
# 38. Amgen Inc Download & Parse complete
# 39. Amphenol Corp A Download & Parse complete
# 40. Anadarko Petroleum Corp Download & Parse complete
# 41. Analog Devices Download & Parse complete
# 42. Aon plc Download & Parse complete
# 43. Apache Corporation Download & Parse complete
# 44. Apartment Investment & Mgmt Download & Parse complete
# 45. Apple Inc. Download & Parse complete
# 46. Applied Materials Inc Download & Parse complete
# 47. Archer-Daniels-Midland Co Download & Parse complete
# 48. Assurant Inc Download & Parse complete
# 49. AT&T Inc Download & Parse complete
# 50. Autodesk Inc Download & Parse complete
# 51. Automatic Data Processing Download & Parse complete
# 52. AutoNation Inc Download & Parse complete
# 53. AutoZone Inc Download & Parse complete
# 54. Avago Technologies Download & Parse complete
# 55. AvalonBay Communities Download & Parse complete
# 56. Avery Dennison Corp Download & Parse complete
# 57. Baker Hughes Inc Download & Parse complete
# 58. Ball Corp Download & Parse complete
# 59. Bank of America Corp Download & Parse complete
# 60. The Bank of New York Mellon Corp. Download & Parse complete
# 61. Bard (C.R.) Inc. Download & Parse complete
# 62. Baxalta Download & Parse complete
# 63. Baxter International Inc. Download & Parse complete
# 64. BB&T Corporation Download & Parse complete
# 65. Becton Dickinson Download & Parse complete
# 66. Bed Bath & Beyond Download & Parse complete
# 67. Best Buy Co. Inc. Download & Parse complete
# 68. BIOGEN IDEC Inc. Download & Parse complete
# 69. BlackRock Download & Parse complete
# 70. Block H&R Download & Parse complete
# 71. Boeing Company Download & Parse complete
# 72. BorgWarner Download & Parse complete
# 73. Boston Properties Download & Parse complete
# 74. Boston Scientific Download & Parse complete
# 75. Bristol-Myers Squibb Download & Parse complete
# 76. Broadcom Corporation Download & Parse complete
# 77. C. H. Robinson Worldwide Download & Parse complete
# 78. CA Download & Parse complete
# 79. Cablevision Systems Corp. Download & Parse complete
# 80. Cabot Oil & Gas Download & Parse complete
# 81. Cameron International Corp. Download & Parse complete
# 82. Campbell Soup Download & Parse complete
# 83. Capital One Financial Download & Parse complete
# 84. Cardinal Health Inc. Download & Parse complete
# 85. Henry Schein Download & Parse complete
# 86. Carmax Inc Download & Parse complete
# 87. Carnival Corp. Download & Parse complete
# 88. Caterpillar Inc. Download & Parse complete
# 89. CBRE Group Download & Parse complete
# 90. CBS Corp. Download & Parse complete
# 91. Celgene Corp. Download & Parse complete
# 92. CenterPoint Energy Download & Parse complete
# 93. CenturyLink Inc Download & Parse complete
# 94. Cerner Download & Parse complete
# 95. CF Industries Holdings Inc Download & Parse complete
# 96. Charles Schwab Corporation Download & Parse complete
# 97. Chesapeake Energy Download & Parse complete
# 98. Chevron Corp. Download & Parse complete
# 99. Chipotle Mexican Grill Download & Parse complete
# 100. Chubb Corp. Download & Parse complete
# 101. CIGNA Corp. Download & Parse complete
# 102. Cimarex Energy Download & Parse complete
# 103. Cincinnati Financial Download & Parse complete
# 104. Cintas Corporation Download & Parse complete
# 105. Cisco Systems Download & Parse complete
# 106. Citigroup Inc. Download & Parse complete
# 107. Citrix Systems Download & Parse complete
# 108. The Clorox Company Download & Parse complete
# 109. CME Group Inc. Download & Parse complete
# 110. CMS Energy Download & Parse complete
# 111. Coach Inc. Download & Parse complete
# 112. The Coca Cola Company Download & Parse complete
# 113. Coca-Cola Enterprises Download & Parse complete
# 114. Cognizant Technology Solutions Download & Parse complete
# 115. Colgate-Palmolive Download & Parse complete
# 116. Columbia Pipeline Group Inc Download & Parse complete
# 117. Comcast A Corp Download & Parse complete
# 118. Comcast Special Corp Class A Download & Parse complete
# 119. Comerica Inc. Download & Parse complete
# 120. Computer Sciences Corp. Download & Parse complete
# 121. ConAgra Foods Inc. Download & Parse complete
# 122. ConocoPhillips Download & Parse complete
# 123. CONSOL Energy Inc. Download & Parse complete
# 124. Consolidated Edison Download & Parse complete
# 125. Constellation Brands Download & Parse complete
# 126. Corning Inc. Download & Parse complete
# 127. Costco Co. Download & Parse complete
# 128. Crown Castle International Corp. Download & Parse complete
# 129. CSX Corp. Download & Parse complete
# 130. Cummins Inc. Download & Parse complete
# 131. CVS Caremark Corp. Download & Parse complete
# 132. D. R. Horton Download & Parse complete
# 133. Danaher Corp. Download & Parse complete
# 134. Darden Restaurants Download & Parse complete
# 135. DaVita Inc. Download & Parse complete
# 136. Deere & Co. Download & Parse complete
# 137. Delphi Automotive Download & Parse complete
# 138. Delta Air Lines Download & Parse complete
# 139. Dentsply International Download & Parse complete
# 140. Devon Energy Corp. Download & Parse complete
# 141. Diamond Offshore Drilling Download & Parse complete
# 142. Discover Financial Services Download & Parse complete
# 143. Discovery Communications-A Download & Parse complete
# 144. Discovery Communications-C Download & Parse complete
# 145. Dollar General Download & Parse complete
# 146. Dollar Tree Download & Parse complete
# 147. Dominion Resources Download & Parse complete
# 148. Dover Corp. Download & Parse complete
# 149. Dow Chemical Download & Parse complete
# 150. Dr Pepper Snapple Group Download & Parse complete
# 151. DTE Energy Co. Download & Parse complete
# 152. Du Pont (E.I.) Download & Parse complete
# 153. Duke Energy Download & Parse complete
# 154. Dun & Bradstreet Download & Parse complete
# 155. E*Trade Download & Parse complete
# 156. Eastman Chemical Download & Parse complete
# 157. Eaton Corporation Download & Parse complete
# 158. eBay Inc. Download & Parse complete
# 159. Ecolab Inc. Download & Parse complete
# 160. Edison Int'l Download & Parse complete
# 161. Edwards Lifesciences Download & Parse complete
# 162. Electronic Arts Download & Parse complete
# 163. EMC Corp. Download & Parse complete
# 164. Emerson Electric Company Download & Parse complete
# 165. Endo International Download & Parse complete
# 166. Ensco plc Download & Parse complete
# 167. Entergy Corp. Download & Parse complete
# 168. EOG Resources Download & Parse complete
# 169. EQT Corporation Download & Parse complete
# 170. Equifax Inc. Download & Parse complete
# 171. Equinix Download & Parse complete
# 172. Equity Residential Download & Parse complete
# 173. Essex Property Trust Inc Download & Parse complete
# 174. Estee Lauder Cos. Download & Parse complete
# 175. Eversource Energy Download & Parse complete
# 176. Exelon Corp. Download & Parse complete
# 177. Expedia Inc. Download & Parse complete
# 178. Expeditors Int'l Download & Parse complete
# 179. Express Scripts Download & Parse complete
# 180. Exxon Mobil Corp. Download & Parse complete
# 181. F5 Networks Download & Parse complete
# 182. Facebook Download & Parse complete
# 183. Fastenal Co Download & Parse complete
# 184. FedEx Corporation Download & Parse complete
# 185. Fidelity National Information Services Download & Parse complete
# 186. Fifth Third Bancorp Download & Parse complete
# 187. First Solar Inc Download & Parse complete
# 188. FirstEnergy Corp Download & Parse complete
# 189. Fiserv Inc Download & Parse complete
# 190. FLIR Systems Download & Parse complete
# 191. Flowserve Corporation Download & Parse complete
# 192. Fluor Corp. Download & Parse complete
# 193. FMC Corporation Download & Parse complete
# 194. FMC Technologies Inc. Download & Parse complete
# 195. Ford Motor Download & Parse complete
# 196. Fossil Download & Parse complete
# 197. Franklin Resources Download & Parse complete
# 198. Freeport-McMoran Cp & Gld Download & Parse complete
# 199. Frontier Communications Download & Parse complete
# 200. GameStop Corp. Download & Parse complete
# 201. Gap (The) Download & Parse complete
# 202. Garmin Ltd. Download & Parse complete
# 203. General Dynamics Download & Parse complete
# 204. General Electric Download & Parse complete
# 205. General Growth Properties Inc. Download & Parse complete
# 206. General Mills Download & Parse complete
# 207. General Motors Download & Parse complete
# 208. Genuine Parts Download & Parse complete
# 209. Genworth Financial Inc. Download & Parse complete
# 210. Gilead Sciences Download & Parse complete
# 211. Goldman Sachs Group Download & Parse complete
# 212. Goodyear Tire & Rubber Download & Parse complete
# 213. Grainger (W.W.) Inc. Download & Parse complete
# 214. Halliburton Co. Download & Parse complete
# 215. Hanesbrands Inc Download & Parse complete
# 216. Harley-Davidson Download & Parse complete
# 217. Harman Int'l Industries Download & Parse complete
# 218. Harris Corporation Download & Parse complete
# 219. Hartford Financial Svc.Gp. Download & Parse complete
# 220. Hasbro Inc. Download & Parse complete
# 221. HCA Holdings Download & Parse complete
# 222. HCP Inc. Download & Parse complete
# 223. Helmerich & Payne Download & Parse complete
# 224. Hess Corporation Download & Parse complete
# 225. Hewlett-Packard Download & Parse complete
# 226. Home Depot Download & Parse complete
# 227. Honeywell Int'l Inc. Download & Parse complete
# 228. Hormel Foods Corp. Download & Parse complete
# 229. Host Hotels & Resorts Download & Parse complete
# 230. Hudson City Bancorp Download & Parse complete
# 231. Humana Inc. Download & Parse complete
# 232. Huntington Bancshares Download & Parse complete
# 233. Illinois Tool Works Download & Parse complete
# 234. Ingersoll-Rand PLC Download & Parse complete
# 235. Intel Corp. Download & Parse complete
# 236. Intercontinental Exchange Download & Parse complete
# 237. International Bus. Machines Download & Parse complete
# 238. International Paper Download & Parse complete
# 239. Interpublic Group Download & Parse complete
# 240. Intl Flavors & Fragrances Download & Parse complete
# 241. Intuit Inc. Download & Parse complete
# 242. Intuitive Surgical Inc. Download & Parse complete
# 243. Invesco Ltd. Download & Parse complete
# 244. Iron Mountain Incorporated Download & Parse complete
# 245. Jacobs Engineering Group Download & Parse complete
# 246. J. B. Hunt Transport Services Download & Parse complete
# 247. Johnson & Johnson Download & Parse complete
# 248. Johnson Controls Download & Parse complete
# 249. JPMorgan Chase & Co. Download & Parse complete
# 250. Juniper Networks Download & Parse complete
# 251. Kansas City Southern Download & Parse complete
# 252. Kellogg Co. Download & Parse complete
# 253. KeyCorp Download & Parse complete
# 254. Keurig Green Mountain Download & Parse complete
# 255. Kimberly-Clark Download & Parse complete
# 256. Kimco Realty Download & Parse complete
# 257. Kinder Morgan Download & Parse complete
# 258. KLA-Tencor Corp. Download & Parse complete
# 259. Kohl's Corp. Download & Parse complete
# 260. Kraft Heinz Co Download & Parse complete
# 261. Kroger Co. Download & Parse complete
# 262. L Brands Inc. Download & Parse complete
# 263. L-3 Communications Holdings Download & Parse complete
# 264. Laboratory Corp. of America Holding Download & Parse complete
# 265. Lam Research Download & Parse complete
# 266. Legg Mason Download & Parse complete
# 267. Leggett & Platt Download & Parse complete
# 268. Lennar Corp. Download & Parse complete
# 269. Level 3 Communications Download & Parse complete
# 270. Leucadia National Corp. Download & Parse complete
# 271. Lilly (Eli) & Co. Download & Parse complete
# 272. Lincoln National Download & Parse complete
# 273. Linear Technology Corp. Download & Parse complete
# 274. Lockheed Martin Corp. Download & Parse complete
# 275. Loews Corp. Download & Parse complete
# 276. Lowe's Cos. Download & Parse complete
# 277. LyondellBasell Download & Parse complete
# 278. M&T Bank Corp. Download & Parse complete
# 279. Macerich Download & Parse complete
# 280. Macy's Inc. Download & Parse complete
# 281. Mallinckrodt Plc Download & Parse complete
# 282. Marathon Oil Corp. Download & Parse complete
# 283. Marathon Petroleum Download & Parse complete
# 284. Marriott Int'l. Download & Parse complete
# 285. Marsh & McLennan Download & Parse complete
# 286. Martin Marietta Materials Download & Parse complete
# 287. Masco Corp. Download & Parse complete
# 288. Mastercard Inc. Download & Parse complete
# 289. Mattel Inc. Download & Parse complete
# 290. McCormick & Co. Download & Parse complete
# 291. McDonald's Corp. Download & Parse complete
# 292. McGraw Hill Financial Download & Parse complete
# 293. McKesson Corp. Download & Parse complete
# 294. Mead Johnson Download & Parse complete
# 295. Westrock Co Download & Parse complete
# 296. Medtronic plc Download & Parse complete
# 297. Merck & Co. Download & Parse complete
# 298. MetLife Inc. Download & Parse complete
# 299. Michael Kors Holdings Download & Parse complete
# 300. Microchip Technology Download & Parse complete
# 301. Micron Technology Download & Parse complete
# 302. Microsoft Corp. Download & Parse complete
# 303. Mohawk Industries Download & Parse complete
# 304. Molson Coors Brewing Company Download & Parse complete
# 305. Mondelez International Download & Parse complete
# 306. Monsanto Co. Download & Parse complete
# 307. Monster Beverage Download & Parse complete
# 308. Moody's Corp Download & Parse complete
# 309. Morgan Stanley Download & Parse complete
# 310. The Mosaic Company Download & Parse complete
# 311. Motorola Solutions Inc. Download & Parse complete
# 312. Murphy Oil Download & Parse complete
# 313. Mylan N.V. Download & Parse complete
# 314. NASDAQ OMX Group Download & Parse complete
# 315. National Oilwell Varco Inc. Download & Parse complete
# 316. Navient Download & Parse complete
# 317. NetApp Download & Parse complete
# 318. Netflix Inc. Download & Parse complete
# 319. Newell Rubbermaid Co. Download & Parse complete
# 320. Newfield Exploration Co Download & Parse complete
# 321. Newmont Mining Corp. (Hldg. Co.) Download & Parse complete
# 322. News Corp. Class A Download & Parse complete
# 323. News Corp. Class B Download & Parse complete
# 324. NextEra Energy Download & Parse complete
# 325. Nielsen Holdings Download & Parse complete
# 326. Nike Download & Parse complete
# 327. NiSource Inc. Download & Parse complete
# 328. Noble Energy Inc Download & Parse complete
# 329. Nordstrom Download & Parse complete
# 330. Norfolk Southern Corp. Download & Parse complete
# 331. Northern Trust Corp. Download & Parse complete
# 332. Northrop Grumman Corp. Download & Parse complete
# 333. NRG Energy Download & Parse complete
# 334. Nucor Corp. Download & Parse complete
# 335. Nvidia Corporation Download & Parse complete
# 336. O'Reilly Automotive Download & Parse complete
# 337. Occidental Petroleum Download & Parse complete
# 338. Omnicom Group Download & Parse complete
# 339. ONEOK Download & Parse complete
# 340. Oracle Corp. Download & Parse complete
# 341. Owens-Illinois Inc Download & Parse complete
# 342. PACCAR Inc. Download & Parse complete
# 343. Parker-Hannifin Download & Parse complete
# 344. Patterson Companies Download & Parse complete
# 345. Paychex Inc. Download & Parse complete
# 346. PayPal Download & Parse complete
# 347. Pentair Ltd. Download & Parse complete
# 348. People's United Financial Download & Parse complete
# 349. Pepco Holdings Inc. Download & Parse complete
# 350. PepsiCo Inc. Download & Parse complete
# 351. PerkinElmer Download & Parse complete
# 352. Perrigo Download & Parse complete
# 353. Pfizer Inc. Download & Parse complete
# 354. PG&E Corp. Download & Parse complete
# 355. Philip Morris International Download & Parse complete
# 356. Phillips 66 Download & Parse complete
# 357. Pinnacle West Capital Download & Parse complete
# 358. Pioneer Natural Resources Download & Parse complete
# 359. Pitney-Bowes Download & Parse complete
# 360. Plum Creek Timber Co. Download & Parse complete
# 361. PNC Financial Services Download & Parse complete
# 362. Polo Ralph Lauren Corp. Download & Parse complete
# 363. PPG Industries Download & Parse complete
# 364. PPL Corp. Download & Parse complete
# 365. Praxair Inc. Download & Parse complete
# 366. Precision Castparts Download & Parse complete
# 367. Priceline.com Inc Download & Parse complete
# 368. Principal Financial Group Download & Parse complete
# 369. Procter & Gamble Download & Parse complete
# 370. Progressive Corp. Download & Parse complete
# 371. Prologis Download & Parse complete
# 372. Prudential Financial Download & Parse complete
# 373. Public Serv. Enterprise Inc. Download & Parse complete
# 374. Public Storage Download & Parse complete
# 375. Pulte Homes Inc. Download & Parse complete
# 376. PVH Corp. Download & Parse complete
# 377. Qorvo Download & Parse complete
# 378. Quanta Services Inc. Download & Parse complete
# 379. QUALCOMM Inc. Download & Parse complete
# 380. Quest Diagnostics Download & Parse complete
# 381. Range Resources Corp. Download & Parse complete
# 382. Raytheon Co. Download & Parse complete
# 383. Realty Income Corporation Download & Parse complete
# 384. Red Hat Inc. Download & Parse complete
# 385. Regeneron Download & Parse complete
# 386. Regions Financial Corp. Download & Parse complete
# 387. Republic Services Inc Download & Parse complete
# 388. Reynolds American Inc. Download & Parse complete
# 389. Robert Half International Download & Parse complete
# 390. Rockwell Automation Inc. Download & Parse complete
# 391. Rockwell Collins Download & Parse complete
# 392. Roper Industries Download & Parse complete
# 393. Ross Stores Download & Parse complete
# 394. Royal Caribbean Cruises Ltd Download & Parse complete
# 395. Ryder System Download & Parse complete
# 396. Salesforce.com Download & Parse complete
# 397. SanDisk Corporation Download & Parse complete
# 398. SCANA Corp Download & Parse complete
# 399. Schlumberger Ltd. Download & Parse complete
# 400. Scripps Networks Interactive Inc. Download & Parse complete
# 401. Seagate Technology Download & Parse complete
# 402. Sealed Air Corp.(New) Download & Parse complete
# 403. Sempra Energy Download & Parse complete
# 404. Sherwin-Williams Download & Parse complete
# 405. Sigma-Aldrich Download & Parse complete
# 406. Signet Jewelers Download & Parse complete
# 407. Simon Property Group Inc Download & Parse complete
# 408. Skyworks Solutions Download & Parse complete
# 409. SL Green Realty Download & Parse complete
# 410. Smucker (J.M.) Download & Parse complete
# 411. Snap-On Inc. Download & Parse complete
# 412. Southern Co. Download & Parse complete
# 413. Southwest Airlines Download & Parse complete
# 414. Southwestern Energy Download & Parse complete
# 415. Spectra Energy Corp. Download & Parse complete
# 416. St Jude Medical Download & Parse complete
# 417. Stanley Black & Decker Download & Parse complete
# 418. Staples Inc. Download & Parse complete
# 419. Starbucks Corp. Download & Parse complete
# 420. Starwood Hotels & Resorts Download & Parse complete
# 421. State Street Corp. Download & Parse complete
# 422. Stericycle Inc Download & Parse complete
# 423. Stryker Corp. Download & Parse complete
# 424. SunTrust Banks Download & Parse complete
# 425. Symantec Corp. Download & Parse complete
# 426. Sysco Corp. Download & Parse complete
# 427. T. Rowe Price Group Download & Parse complete
# 428. Target Corp. Download & Parse complete
# 429. TE Connectivity Ltd. Download & Parse complete
# 430. TECO Energy Download & Parse complete
# 431. Tegna Download & Parse complete
# 432. Tenet Healthcare Corp. Download & Parse complete
# 433. Teradata Corp. Download & Parse complete
# 434. Tesoro Petroleum Co. Download & Parse complete
# 435. Texas Instruments Download & Parse complete
# 436. Textron Inc. Download & Parse complete
# 437. The Hershey Company Download & Parse complete
# 438. The Travelers Companies Inc. Download & Parse complete
# 439. Thermo Fisher Scientific Download & Parse complete
# 440. Tiffany & Co. Download & Parse complete
# 441. Time Warner Inc. Download & Parse complete
# 442. Time Warner Cable Inc. Download & Parse complete
# 443. TJX Companies Inc. Download & Parse complete
# 444. Torchmark Corp. Download & Parse complete
# 445. Total System Services Download & Parse complete
# 446. Tractor Supply Company Download & Parse complete
# 447. Transocean Download & Parse complete
# 448. TripAdvisor Download & Parse complete
# 449. Twenty-First Century Fox Class A Download & Parse complete
# 450. Twenty-First Century Fox Class B Download & Parse complete
# 451. Tyson Foods Download & Parse complete
# 452. Tyco International Download & Parse complete
# 453. U.S. Bancorp Download & Parse complete
# 454. Under Armour Download & Parse complete
# 455. Union Pacific Download & Parse complete
# 456. United Continental Holdings Download & Parse complete
# 457. United Health Group Inc. Download & Parse complete
# 458. United Parcel Service Download & Parse complete
# 459. United Rentals Download & Parse complete
# 460. United Technologies Download & Parse complete
# 461. Universal Health Services Download & Parse complete
# 462. Unum Group Download & Parse complete
# 463. Urban Outfitters Download & Parse complete
# 464. V.F. Corp. Download & Parse complete
# 465. Valero Energy Download & Parse complete
# 466. Varian Medical Systems Download & Parse complete
# 467. Ventas Inc Download & Parse complete
# 468. Verisign Inc. Download & Parse complete
# 469. Verisk Analytics Download & Parse complete
# 470. Verizon Communications Download & Parse complete
# 471. Vertex Pharmaceuticals Inc Download & Parse complete
# 472. Viacom Inc. Download & Parse complete
# 473. Visa Inc. Download & Parse complete
# 474. Vornado Realty Trust Download & Parse complete
# 475. Vulcan Materials Download & Parse complete
# 476. Wal-Mart Stores Download & Parse complete
# 477. Walgreens Boots Alliance Download & Parse complete
# 478. The Walt Disney Company Download & Parse complete
# 479. Waste Management Inc. Download & Parse complete
# 480. Waters Corporation Download & Parse complete
# 481. Anthem Inc. Download & Parse complete
# 482. Wells Fargo Download & Parse complete
# 483. Welltower Inc. Download & Parse complete
# 484. Western Digital Download & Parse complete
# 485. Western Union Co Download & Parse complete
# 486. Weyerhaeuser Corp. Download & Parse complete
# 487. Whirlpool Corp. Download & Parse complete
# 488. Whole Foods Market Download & Parse complete
# 489. Williams Cos. Download & Parse complete
# 490. Wisconsin Energy Corporation Download & Parse complete
# 491. Wyndham Worldwide Download & Parse complete
# 492. Wynn Resorts Ltd Download & Parse complete
# 493. Xcel Energy Inc Download & Parse complete
# 494. Xerox Corp. Download & Parse complete
# 495. Xilinx Inc Download & Parse complete
# 496. XL Capital Download & Parse complete
# 497. Xylem Inc. Download & Parse complete
# 498. Yahoo Inc. Download & Parse complete
# 499. Yum! Brands Inc Download & Parse complete
# 500. Zimmer Biomet Holdings Download & Parse complete
# 501. Zions Bancorp Download & Parse complete
# 502. Zoetis Download & Parse complete

# %% [markdown]
# To avoid survivors bias which might accidentally happen if we tend to use survived companies from 2016 S&P500 constituent, we will only use stocks that has existed from 2010.

# %%
import process as proc
import numpy as np

spy = proc.read_mkt_data('mkt_price_volume.csv')
spy = spy['SPY:Price']
spy.name = 'SPY'
# Preprocess data
stocks = proc.read_stock_data('S&P500_stocks_price.csv', verbose=True)
stocks = proc.fill_missing_values(stocks)
stocks = stocks.join(spy)
# Out:
# List of companies dropped due to insufficient data
# ABBV
# ACE
# ADT
# GAS
# ARG
# AA
# ALLE
# GOOG
# ALTR
# BXLT
# BRCM
# CVC
# CAM
# CCE
# CPGX
# CMCSK
# CSC
# CNX
# DLPH
# EMC
# ESV
# FB
# FOSL
# GM
# GNW
# HCA
# HCBK
# GMCR
# KMI
# KHC
# LM
# LYB
# MNK
# MPC
# MHFI
# WRK
# KORS
# NAVI
# NWSA
# NWS
# NLSN
# OI
# PYPL
# POM
# PSX
# PCL
# PCP
# QRVO
# SNDK
# SIAL
# HOT
# TE
# TGNA
# THC
# TWC
# TRIP
# TYC
# WBA
# ANTM
# XYL
# ZBH
# ZTS

# %% [markdown]
# To derive beta value for every stock, we have to run linear regression where x domain is market and y domain is specific stock we want to calculate. We do not want to use stocks that have poor correlation with the market because this means that price movement is somewhat random when compared to the market. We want stocks that show strong relationship to market.

# %%
import run
import matplotlib.pyplot as plt
import utility as util
# Show matplotlib plots inline (nicely formatted in the notebook)
# %matplotlib inline

capm = run.get_stocks_CAPM(stocks)
#capm = capm.sort_values(['beta'], ascending=[1]) 
#capm = capm[(capm['corr'] > capm['corr'].quantile(0.5))]
#print capm
util.plot_stock_CAPM(stocks, 'FIS', "beta: 0.937")
util.plot_stock_CAPM(stocks, 'CMI', 'beta: 1.477')
capm.plot(kind='scatter', x='beta', y='corr', title='stocks in S&P500')
plt.show()

#print capm.head()

# %% [markdown]
# <font color='gray' size=4> (6) Portfolio Construction Strategy: Weight Allocation </font>

# %% [markdown]
# Final step is to decide optimal allocation for each stocks that would be in our portfolio. Point here is that even though we have same stocks in our portfolio, how we allocate weights to them can greatly affect in overall performance of our portfolio. In this project, we optimize this weights using historical data. We use optimizer which maximize our given function. We will compare between three metric function. (1) Function that maximize Sharpe ratio (2) Function that maximize return (3) Function that minimize risk/variance

# %% [markdown]
# <font color='gray' size=4> (7) Simulation </font>

# %% [markdown]
# Now we are ready to run simulation and see how our constructed portfolio can actually outperform market index.
#
# 1) Forecasting S&P500 return from current and past data: We will use data from 2010 to 2015 for training. Models that can be used here is (1)KNN, (2)DecisionTree, (3)SVR, (4)Random Forest. Optimal parameter for each model is  KNN(n_neighbors=27, weights='distance'), DecisionTree(max_depth=3), SVR(kernel='rbf', C=10.0, epsilon='0.001'), Random Forest(max_depth=3, n_estimator='40').
#
# 2) Selecting appropriate stocks depending on market forecast: Parameter option for this section is (1) Number of company is portfolio(default = 20) (2) Correlation Threshold(default = 0.7)
#
# 3) Finding optimal weights for stocks that maximize portfolio's return: Optimizing function to be used here are (1) Maximizing Sharpe Ratio (2) Maximizing Return (3) Minimizing Risk
#
# Our simulation will run from 2016-01-04 to 2016-12-31. We make 5 day ahead S&P500 forecast everyday. Whenever there is signal of changing from bull to bear or bear to bull, we re-select our stocks depending on market forecast. By default, we will include top 20 high/low beta companies that have correlation value greater than it's 60% quantile.

# %%
import pandas as pd
import utility as util
import process as proc
from IPython.display import display # Allows the use of display() for DataFrames
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np
import run
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# Show matplotlib plots inline (nicely formatted in the notebook)
# %matplotlib inline

day_1 = 1
day_5 = 5
day_10 = 10
day_20 = 20

# Read data from CSV files
raw_data = proc.read_mkt_data('mkt_price_volume.csv')

# Fill missing value
raw_data = proc.fill_missing_values(raw_data)
price_data = proc.extract_columns(raw_data, 'Price')
price_data.drop('GLF:Price', axis = 1, inplace = True)
price_data.drop('NAS:Price', axis = 1, inplace = True)

day_1_return = proc.price_to_return(price_data, 'Price', 'Return(1D)', day_1)
day_5_return = proc.price_to_return(price_data, 'Price', 'Return(5D)', day_5)
day_10_return = proc.price_to_return(price_data, 'Price', 'Return(10D)', day_10)
day_20_return = proc.price_to_return(price_data, 'Price', 'Return(20D)', day_20)

#target
target = day_10_return['SPY:Return(10D)'].shift(-5)
target.name = target.name.replace('Return(10D)', 'Target')

#features
df = day_10_return
df = df.join(day_1_return['SPY:Return(1D)'])
df = df.join(day_5_return['SPY:Return(5D)'])
df = df.join(day_20_return['SPY:Return(20D)'])

train_range = ["2010-01-01", "2015-12-31"]

X = df[day_20:-5]
y = target[day_20:-5]

X_train = X.ix[train_range[0]:train_range[1]]
y_train = y.ix[train_range[0]:train_range[1]]

X_train = X_train.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)

#reg = RandomForestRegressor(n_estimators=30, max_depth=3)
#reg = DecisionTreeRegressor(max_depth=3)
#reg = KNeighborsRegressor(n_neighbors=21, weights = 'distance')
reg = SVR(kernel = 'rbf', C = 10.0, epsilon = 0.001)

reg = reg.fit(X_train, y_train)
print "Training Done"
#Stock datas
spy = proc.read_mkt_data('mkt_price_volume.csv')
spy = spy[['SPY:Price']]
spy = spy.rename(columns = {'SPY:Price':'SPY'})
# Preprocess data
stocks = proc.read_stock_data('S&P500_stocks_price.csv', verbose=False)
stocks = proc.fill_missing_values(stocks)
stocks = spy.join(stocks)
stocks = stocks[day_20:-5]
# Out:
# Training Done

# %%
simulation_range = ["2016-01-01", "2016-12-31"]
portfolio_sharpe = run.simulation(reg, X, y, stocks, simulation_range, rollback=252, n_company=30, corr = 0.7, method='sharpe')
portfolio_return = run.simulation(reg, X, y, stocks, simulation_range, rollback=252, n_company=30, corr = 0.7, method='return')
portfolio_risk = run.simulation(reg, X, y, stocks, simulation_range, rollback=252, n_company=30, corr = 0.7, method='risk')
# Out:
# [2016-01-25T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.00335095789
# [2016-02-05T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 0.986580302881
# [2016-02-16T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.00152327613
# [2016-03-28T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.00811196208
# [2016-03-29T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.02137146185
# [2016-04-05T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.00824546839
# [2016-04-06T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.01313991384
# [2016-04-07T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 0.996840080042
# [2016-04-12T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.00183170006
# [2016-04-29T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.02242911011
# [2016-05-02T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.02675584819
# [2016-05-03T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.00723090364
# [2016-05-06T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.02089385791
# [2016-05-09T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.01641848376
# [2016-05-10T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.02640020191
# [2016-05-17T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.00851742377
# [2016-05-18T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.00490411542
# [2016-05-19T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 0.997784752559
# [2016-05-20T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 0.996317903858
# [2016-06-13T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 0.990247690458
# [2016-06-20T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 0.997523629627
# [2016-06-24T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 0.961533535653
# [2016-07-01T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 0.998661854438
# [2016-07-27T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.07004709741
# [2016-07-28T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.07074727449
# [2016-07-29T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.06902301716
# [2016-08-01T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.06856519759
# [2016-08-02T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.05669595953
# [2016-08-05T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.05843967637
# [2016-08-26T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.04017998616
# [2016-08-29T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.04582350882
# [2016-08-30T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.05339024476
# [2016-08-31T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.04948250495
# [2016-09-09T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.02475026002
# [2016-09-16T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.02323745426
# [2016-09-19T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.03076387565
# [2016-09-20T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.03863318122
# [2016-09-29T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.02243826838
# [2016-09-30T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.03282797468
# [2016-10-12T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.03234821451
# [2016-10-18T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.02810207403
# [2016-10-28T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.0149092934
# [2016-11-07T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.02462028032
# [2016-12-02T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.04665433641
# [2016-12-05T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.04815677892
# [2016-01-25T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 0.957965155704
# [2016-02-05T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 0.93845680363
# [2016-02-16T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 0.95203529138
# [2016-03-28T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.01518584776
# [2016-03-29T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.02397692033
# [2016-04-05T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.00480804116
# [2016-04-06T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.01002805071
# [2016-04-07T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 0.999236394591
# [2016-04-12T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.0104816275
# [2016-04-29T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 0.922099153955
# [2016-05-02T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 0.932516866482
# [2016-05-03T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 0.919410204042
# [2016-05-06T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 0.931481608496
# [2016-05-09T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 0.933139204504
# [2016-05-10T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 0.944297074769
# [2016-05-17T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 0.937973384171
# [2016-05-18T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 0.944876641027
# [2016-05-19T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 0.94162231379
# [2016-05-20T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 0.948048162851
# [2016-06-13T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 0.966939857454
# [2016-06-20T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 0.970752612858
# [2016-06-24T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 0.953595167608
# [2016-07-01T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.00330754425
# [2016-07-27T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.06503988563
# [2016-07-28T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.07056759751
# [2016-07-29T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.05839254927
# [2016-08-01T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.06172388668
# [2016-08-02T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.04698878794
# [2016-08-05T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.05541951087
# [2016-08-26T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.04559981031
# [2016-08-29T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.05715863114
# [2016-08-30T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.06328620476
# [2016-08-31T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.06229361082
# [2016-09-09T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.03563054342
# [2016-09-16T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.02787833596
# [2016-09-19T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.03099640289
# [2016-09-20T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.03007906782
# [2016-09-29T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.01739342526
# [2016-09-30T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.024885972
# [2016-10-12T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.01220250683
# [2016-10-18T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.00731642326
# [2016-10-28T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.01801153125
# [2016-11-07T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.04528044177
# [2016-12-02T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.2185808807
# [2016-12-05T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.22278991055
# [2016-01-25T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 0.989353951752
# [2016-02-05T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 0.958031559427
# [2016-02-16T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 0.972056986314
# [2016-03-28T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.06458994675
# [2016-03-29T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.07896908268
# [2016-04-05T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.06961549322
# [2016-04-06T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.07676498839
# [2016-04-07T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.06008246724
# [2016-04-12T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.05940458258
# [2016-04-29T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.06307360085
# [2016-05-02T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.0688694241
# [2016-05-03T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.04839014469
# [2016-05-06T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.06289627142
# [2016-05-09T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.06002561556
# [2016-05-10T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.06911608148
# [2016-05-17T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.05034863834
# [2016-05-18T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.04556255976
# [2016-05-19T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.04039453301
# [2016-05-20T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.03909357224
# [2016-06-13T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.01582248317
# [2016-06-20T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.02280119697
# [2016-06-24T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 0.979751272697
# [2016-07-01T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.02778681457
# [2016-07-27T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.08198810139
# [2016-07-28T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.08276722415
# [2016-07-29T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.07740934591
# [2016-08-01T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.07762327089
# [2016-08-02T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.06448883504
# [2016-08-05T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.06885202083
# [2016-08-26T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.05341135195
# [2016-08-29T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.05931037606
# [2016-08-30T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.06788392244
# [2016-08-31T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.06283308037
# [2016-09-09T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.03701266039
# [2016-09-16T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.03019437269
# [2016-09-19T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.03702483262
# [2016-09-20T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.0423451036
# [2016-09-29T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.02747457383
# [2016-09-30T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.03889414206
# [2016-10-12T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.03795096108
# [2016-10-18T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.02932794673
# [2016-10-28T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.02403297062
# [2016-11-07T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.03402677914
# [2016-12-02T00:00:00.000000000]Market status change: bull -> bear, current portfolio value: 1.10403422764
# [2016-12-05T00:00:00.000000000]Market status change: bear -> bull, current portfolio value: 1.10682294625

# %%
import utility as util
import process as proc

spy = spy.ix[simulation_range[0]:simulation_range[1]]
spy = proc.normalize_firstrow(spy)
portfolio_sharpe = portfolio_sharpe.rename(columns = {'value':'Max Sharpe Ratio'})
portfolio_return = portfolio_return.rename(columns = {'value':'Max Return'})   
portfolio_risk = portfolio_risk.rename(columns = {'value':'Min Risk'})                                                         
spy = spy.rename(columns = {'SPY:Price':'SPY'})
result = spy.join(portfolio_sharpe[['Max Sharpe Ratio']])
result = result.join(portfolio_return[['Max Return']])
result = result.join(portfolio_risk[['Min Risk']])
util.plot_data(result, title='Model: SVR, # of company in portfolio: 30')

# %%
util.plot_data(portfolio['return'], title='Prediction for S&P500 cumulatie return', ylable='return')
util.plot_data(portfolio['market'], title='bull market: 1, bear market: -1', ylable='market status')
